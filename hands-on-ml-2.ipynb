# %%
print("Welcome to the KI-World!")
# Out:
# Welcome to the KI-World!

# %% [markdown]
# This project requires Python 3.7 or above:

# %%
import sys
assert sys.version_info >= (3, 7), "This code requires Python 3.7 or higher."

print(sys.executable)
# Out:
# /Users/saied/micromamba/envs/ml-intro/bin/python

# %% [markdown]
# It also requires Scikit-Learn ≥ 1.0.1:

# %%
from packaging import version
import sklearn

assert version.parse(sklearn.__version__) >= version.parse("1.0.1")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 from packaging import version
# ----> 2 import sklearn
#       4 assert version.parse(sklearn.__version__) >= version.parse("1.0.1")
#
# ModuleNotFoundError: No module named 'sklearn'
